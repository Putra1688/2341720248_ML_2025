# %% [markdown]
# <a href="https://colab.research.google.com/github/Putra1688/MachineLearning-2025-22/blob/main/TG9_2341720248.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🍈 JS09 - KLASIFIKASI**

# %% [markdown]
# <table border="1">
#   <tr>
#     <td>Nama</td>
#     <td>: Rangga Dwi Saputra</td>
#   </tr>
#   <tr>
#     <td>NIM</td>
#     <td>: 2341720248</td>
#   </tr>
# </table>

# %% [markdown]
# # **🥚 TUGAS 2**

# %% [markdown]
# ## Task
# Buat model klasifikasi Multinomial Naive Bayes menggunakan kumpulan data "spam.csv".
#
# 1. Gunakan CountVectorizer dengan stop_words diaktifkan untuk ekstraksi fitur dan evaluasi hasilnya.
# 2. Gunakan TF-IDF dengan stop_words diaktifkan untuk ekstraksi fitur, evaluasi hasilnya, dan bandingkan dengan hasil dari langkah 1.
# 3. Simpulkan fitur mana yang terbaik untuk kumpulan data "spam.csv".

# %% [markdown]
# ## 1] Load data

# %%
import pandas as pd

df_spam = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machine Learning/JS09-Klasifikasi/spam.csv', encoding='latin-1')
df_spam.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ## 2] Preprocessing
# Clean and prepare the text data, including encoding labels and handling any missing values.

# %%
# Drop the last three columns
df_spam = df_spam.drop(df_spam.iloc[:, 2:], axis=1)

# Rename columns
df_spam.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)

# Check for missing values
print("Missing values before handling:")
print(df_spam.isnull().sum())

# Encode the 'label' column
new_labels = {
    'spam': 1,
    'ham': 0
}
df_spam['label'] = df_spam['label'].map(new_labels)

# Display the first few rows of the preprocessed DataFrame
display(df_spam.head())
# Out:
# Missing values before handling:
# label    0
# text     0
# dtype: int64
#    label                                               text
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## 3] Split data
# Split the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

# Separate features (X) and target (y)
X = df_spam['text']
y = df_spam['label']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (4457,)
# Shape of X_test: (1115,)
# Shape of y_train: (4457,)
# Shape of y_test: (1115,)

# %% [markdown]
# ## 4] Feature extraction (countvectorizer with stop words)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate CountVectorizer with English stop words
bow = CountVectorizer(stop_words='english')

# Fit and transform X_train
X_train_cv = bow.fit_transform(X_train)

# Transform X_test
X_test_cv = bow.transform(X_test)

# Print the shapes
print("Shape of X_train_cv:", X_train_cv.shape)
print("Shape of X_test_cv:", X_test_cv.shape)
# Out:
# Shape of X_train_cv: (4457, 7466)
# Shape of X_test_cv: (1115, 7466)

# %% [markdown]
# ## 5] Train and evaluate model (countvectorizer)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Instantiate MultinomialNB
mnb_cv = MultinomialNB()

# Fit model
mnb_cv.fit(X_train_cv, y_train)

# Predict with training data
y_pred_train_cv = mnb_cv.predict(X_train_cv)

# Evaluate accuracy on training data
acc_train_cv = accuracy_score(y_train, y_pred_train_cv)
print(f'Hasil akurasi data train (CountVectorizer): {acc_train_cv}')

# Predict with testing data
y_pred_test_cv = mnb_cv.predict(X_test_cv)

# Evaluate accuracy on testing data
acc_test_cv = accuracy_score(y_test, y_pred_test_cv)
print(f'Hasil akurasi data test (CountVectorizer): {acc_test_cv}')
# Out:
# Hasil akurasi data train (CountVectorizer): 0.9946152120260264
# Hasil akurasi data test (CountVectorizer): 0.9829596412556054

# %% [markdown]
# ## 6] Feature extraction (tf-idf with stop words)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer with English stop words
tfidf = TfidfVectorizer(stop_words='english')

# Fit and transform X_train
X_train_tfidf = tfidf.fit_transform(X_train)

# Transform X_test
X_test_tfidf = tfidf.transform(X_test)

# Print the shapes
print("Shape of X_train_tfidf:", X_train_tfidf.shape)
print("Shape of X_test_tfidf:", X_test_tfidf.shape)
# Out:
# Shape of X_train_tfidf: (4457, 7466)
# Shape of X_test_tfidf: (1115, 7466)

# %% [markdown]
# ## 7] Train and evaluate model (tf-idf)

# %%
# Instantiate MultinomialNB
mnb_tfidf = MultinomialNB()

# Fit model
mnb_tfidf.fit(X_train_tfidf, y_train)

# Predict with training data
y_pred_train_tfidf = mnb_tfidf.predict(X_train_tfidf)

# Evaluate accuracy on training data
acc_train_tfidf = accuracy_score(y_train, y_pred_train_tfidf)
print(f'Hasil akurasi data train (TF-IDF): {acc_train_tfidf}')

# Predict with testing data
y_pred_test_tfidf = mnb_tfidf.predict(X_test_tfidf)

# Evaluate accuracy on testing data
acc_test_tfidf = accuracy_score(y_test, y_pred_test_tfidf)
print(f'Hasil akurasi data test (TF-IDF): {acc_test_tfidf}')
# Out:
# Hasil akurasi data train (TF-IDF): 0.9842943684092439
# Hasil akurasi data test (TF-IDF): 0.9605381165919282

# %% [markdown]
# ## 8] Compare results
#
# Compare the evaluation results from the CountVectorizer and TF-IDF models.

# %%
print(f'Accuracy of Multinomial Naive Bayes with CountVectorizer on training data: {acc_train_cv}')
print(f'Accuracy of Multinomial Naive Bayes with CountVectorizer on testing data: {acc_test_cv}')
print(f'Accuracy of Multinomial Naive Bayes with TF-IDF on training data: {acc_train_tfidf}')
print(f'Accuracy of Multinomial Naive Bayes with TF-IDF on testing data: {acc_test_tfidf}')
# Out:
# Accuracy of Multinomial Naive Bayes with CountVectorizer on training data: 0.9946152120260264
# Accuracy of Multinomial Naive Bayes with CountVectorizer on testing data: 0.9829596412556054
# Accuracy of Multinomial Naive Bayes with TF-IDF on training data: 0.9842943684092439
# Accuracy of Multinomial Naive Bayes with TF-IDF on testing data: 0.9605381165919282

# %% [markdown]
# ## 9] Conclusion
#
# Dalam konteks klasifikasi spam menggunakan Multinomial Naive Bayes, model Multinomial Naive Bayes dengan fitur yang diekstraksi menggunakan CountVectorizer menghasilkan akurasi yang lebih tinggi pada data uji dibandingkan dengan menggunakan TF-IDF.
