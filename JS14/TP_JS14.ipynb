# %% [markdown]
# <a href="https://colab.research.google.com/github/Putra1688/2341720248_ML_2025/blob/main/JS14/TG14_2341720248_Rangga_Dwi_Saputra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table border="1">
#   <tr>
#     <td>Nama</td>
#     <td>: Rangga Dwi Saputra</td>
#   </tr>
#   <tr>
#     <td>NIM</td>
#     <td>: 2341720248</td>
#   </tr>
# </table>

# %% [markdown]
# # TUGAS PRAKTIKUM
# Selesaikan model CNN Praktikum 2 dengan menambahkan layer Flatten dan Dense, kemudian kompilasi dan latih pada dataset CIFAR-10. Evaluasi kinerjanya, targetkan akurasi 80%, dan plot akurasi pelatihan dan validasi. Selanjutnya, muat dan proses awal kumpulan data MNIST, tentukan model CNN baru untuk klasifikasi MNIST, lalu kompilasi, latih, dan evaluasi model MNIST ini. Terakhir, rangkum modifikasi yang dilakukan pada model Praktikum 2, akurasi yang dicapai, dan presentasikan model MNIST CNN yang baru dibuat beserta hasil pelatihan dan evaluasinya, termasuk akurasi pengujian akhir.

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2807213132.py in <cell line: 0>()
# ----> 1 model.add(layers.Flatten())
#       2 model.add(layers.Dense(64, activation='relu'))
#       3 model.add(layers.Dense(10))
#
# NameError: name 'model' is not defined

# %% [markdown]
# Upaya sebelumnya gagal karena objek `model` tidak ditentukan saat kode untuk menambahkan layer Flatten dan Dense dijalankan. Ini berarti sel sebelumnya (`m-fAktSTW9wN`) yang menginisialisasi model dan menambahkan lapisan konvolusionalnya tidak dijalankan atau statusnya hilang. Untuk memperbaikinya, blok kode saat ini harus terlebih dahulu menginisialisasi ulang model dengan lapisan konvolusionalnya sebelum menambahkan lapisan Flatten dan Dense, untuk memastikan objek model didefinisikan dan terstruktur dengan benar.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Blok kode sebelumnya berhasil menyelesaikan `NameError` dengan menginisialisasi ulang model dengan lapisan konvolusionalnya sebelum menambahkan lapisan Flatten dan Dense. `UserWarning` bukanlah kesalahan yang menghalangi pembuatan model, sehingga arsitektur model kini telah selesai sebagaimana dimaksud.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Arsitektur model Praktikum 2 telah selesai. Langkah logis berikutnya, sesuai dengan alur dan original notebook's task, adalah mengkompilasi model.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Model telah diinisialisasi ulang dan arsitekturnya (convolutional, pooling, flatten, and dense layers) telah selesai. Langkah selanjutnya adalah mengkompilasi model sesuai alur dan tugas notebook asli, menentukan pengoptimal, fungsi kerugian, dan metrik evaluasi.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Model telah diinisialisasi ulang dan arsitekturnya (convolutional, pooling, flatten, and dense layers) telah selesai. Langkah selanjutnya adalah mengkompilasi model sesuai dengan alur dan tugas notebook asli, menentukan pengoptimal, fungsi kerugian, dan metrik evaluasi

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Arsitektur model telah selesai dan kini telah berhasil dikompilasi. Langkah selanjutnya, seperti yang diuraikan dalam tugas utama, adalah melatih model pada data `train_images` dan `train_labels`, dan memvalidasinya menggunakan `test_images` dan `test_labels` selama jumlah epoch yang ditentukan. Hal ini akan memenuhi bagian tugas 'melatihnya pada kumpulan data CIFAR-10'.

# %%
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 51ms/step - accuracy: 0.3364 - loss: 1.7840 - val_accuracy: 0.5578 - val_loss: 1.2434
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 50ms/step - accuracy: 0.5672 - loss: 1.2215 - val_accuracy: 0.6162 - val_loss: 1.0719
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 75s 48ms/step - accuracy: 0.6331 - loss: 1.0334 - val_accuracy: 0.6459 - val_loss: 1.0028
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 75s 48ms/step - accuracy: 0.6757 - loss: 0.9224 - val_accuracy: 0.6733 - val_loss: 0.9399
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 47ms/step - accuracy: 0.7022 - loss: 0.8482 - val_accuracy: 0.6931 - val_loss: 0.9005
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 74s 47ms/step - accuracy: 0.7219 - loss: 0.7969 - val_accuracy: 0.6785 - val_loss: 0.9278
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 47ms/step - accuracy: 0.7410 - loss: 0.7410 - val_accuracy: 0.6999 - val_loss: 0.8722
# Epoch 8/10
# ...
