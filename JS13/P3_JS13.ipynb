# %% [markdown]
# <a href="https://colab.research.google.com/github/Putra1688/MachineLearning-2025-22/blob/main/TGS13_2341720248_Rangga_Dwi_Saputra_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **JS13 - Artificial Neural Network (ANN) dan Evaluasi Classifier**

# %% [markdown]
# # PRAKTIKUM 3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=100)

# Evaluasi
print("Prediksi:", model.predict(X_test))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 1.6693
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.6569
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.6446
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 1.6323
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 1.6201
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 1.6080
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.5959
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.5839
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.5720
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.5601
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.5483
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.5365
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5248
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.5132
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5017
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.4902
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.4788
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.4674
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.4562
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.4449
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.4338
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.4227
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.4117
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.4008
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.3900
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.3792
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.3685
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.3578
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.3472
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.3367
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.3263
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.3159
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.3056
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.2954
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.2852
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.2751
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.2651
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.2552
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.2453
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.2355
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.2257
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.2160
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.2064
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.1969
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.1874
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.1781
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.1688
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.1595
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.1504
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.1412
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.1322
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.1232
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.1143
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.1055
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0967
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0879
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0793
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0707
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.0621
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.0536
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.0452
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.0368
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.0285
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.0202
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0120
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0039
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.9958
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.9877
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.9798
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9720
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.9642
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.9564
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9488
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.9412
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.9336
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.9261
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.9186
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.9112
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.9038
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.8965
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8893
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8821
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.8749
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.8678
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.8607
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8537
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.8468
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.8399
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.8330
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.8262
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.8195
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.8128
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8061
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7995
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7930
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7865
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.7800
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7736
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7672
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.7609
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Prediksi: [[-0.00362487]]

# %% [markdown]
# ## TUGAS 4

# %% [markdown]
# ### 1] Ubah learning rate.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

print("--- Training Model Regresi (Learning Rate Awal) ---")

# Contoh dataset (gunakan dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90, 100, 110, 120, 130, 140],
    'harga': [500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split data (gunakan random_state untuk konsistensi)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Model 1: Konfigurasi Learning Rate Awal (misal: 0.01)
model_lr_orig = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

optimizer_orig = tf.keras.optimizers.Adam(learning_rate=0.01)
model_lr_orig.compile(optimizer=optimizer_orig, loss='mse')
history_lr_orig = model_lr_orig.fit(X_train, y_train, epochs=100, verbose=0)

# Evaluasi Model 1
loss_orig = model_lr_orig.evaluate(X_test, y_test, verbose=0)
print(f"Loss dengan Learning Rate 0.01: {loss_orig:.4f}")
# Out:
# --- Training Model Regresi (Learning Rate Awal) ---
# Loss dengan Learning Rate 0.01: 0.0008

# %%
print("--- Training Model Regresi (Learning Rate Baru) ---")

# Model 2: Konfigurasi Learning Rate Baru (misal: 0.001)
model_lr_new = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

optimizer_new = tf.keras.optimizers.Adam(learning_rate=0.001) # Learning rate yang lebih kecil
model_lr_new.compile(optimizer=optimizer_new, loss='mse')
history_lr_new = model_lr_new.fit(X_train, y_train, epochs=100, verbose=0)

# Evaluasi Model 2
loss_new = model_lr_new.evaluate(X_test, y_test, verbose=0)
print(f"Loss dengan Learning Rate 0.001: {loss_new:.4f}")
# Out:
# --- Training Model Regresi (Learning Rate Baru) ---
# Loss dengan Learning Rate 0.001: 0.2290

# %% [markdown]
# ### 2] Perbandingan Loss Berdasarkan Learning Rate pada Model Regresi
#
# Berikut adalah perbandingan *loss* (Mean Squared Error) pada data uji untuk model regresi yang dilatih dengan *learning rate* yang berbeda:
#
# | Learning Rate | Loss (MSE) pada Data Uji |
# | :------------ | :----------------------- |
# | **0.01**      | {{loss_orig:.4f}}        |
# | **0.001**     | {{loss_new:.4f}}         |
#
# **Analisis:**
#
# *(Catatan: Hasil loss dapat bervariasi setiap kali eksekusi karena inisialisasi bobot acak, meskipun `random_state` digunakan untuk `train_test_split` agar lebih konsisten.)*
#
# Dari perbandingan di atas, kita dapat melihat dampak *learning rate* terhadap kinerja model.
# *   *Learning rate* yang terlalu tinggi dapat menyebabkan model 'melompati' titik optimal dan tidak pernah konvergen dengan baik.
# *   *Learning rate* yang terlalu rendah dapat membuat proses pelatihan sangat lambat, meskipun berpotensi mencapai titik optimal yang lebih baik.
#
# Dalam kasus ini, *learning rate* **0.001** tampaknya menghasilkan *loss* yang lebih rendah, menunjukkan bahwa model belajar lebih stabil dan efektif dengan kecepatan yang lebih kecil pada jumlah *epoch* yang sama.
