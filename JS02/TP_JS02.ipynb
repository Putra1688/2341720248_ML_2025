# %% [markdown]
# # **📀 JS02 - Pemahaman Data dan Pra Pengolahan Data**

# %%
# !pip install -q pandas matplotlib numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **TUGAS PRAKTIKUM**
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugasnya adalah,

# %% [markdown]
# ## 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %% [markdown]
# Datanya dimuat dulu

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from google.colab import files

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/wbc.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cols_to_drop = ['id', 'Unnamed: 32']
useful_cols = df.drop(cols_to_drop, axis=1).columns

# %% [markdown]
# ## 2. Lakukan proses encoding pada kolom "diagnosis".

# %%
le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %% [markdown]
# ## 3. Lakukan proses standardisasi pada semua kolom yang memiliki nilai numerik.

# %%
scaler = StandardScaler()
numerical_cols = useful_cols.drop('diagnosis')
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
display(df.head())
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1     1.097064     -2.073335        1.269934   0.984375
# 1    842517          1     1.829821     -0.353632        1.685955   1.908708
# 2  84300903          1     1.579888      0.456187        1.566503   1.558884
# 3  84348301          1    -0.768909      0.253732       -0.592687  -0.764464
# 4  84358402          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
# ...
